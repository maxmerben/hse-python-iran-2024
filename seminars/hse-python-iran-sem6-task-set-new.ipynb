# %% [markdown]
# # Дополнительная-дополнительная задача №6

# %% [markdown]
# ### Задача 6.X. Страшные множества

# %% [markdown]
# Даны алфавиты нескольких языков. Код ниже делает из них множества:

# %%
alphabets = {
    "абхазский": "абвгӷдезӡикқҟлмнопԥрстҭуфхҳцҵчҷҽҿшыҩџьә",
    "беларусский": "абвгдеёжзійклмнопрстуўфхцчшыьэюя",
    "русский": "абвгдеёжзийклмнопрстуфхцчшщъыьэюя",
    "таджикский": "абвгғдеёжзиӣйкқлмнопрстуӯфхҳчҷшъэюя",
    "чувашский": "аӑбвгдеёӗжзийклмнопрсҫтуӳфхцчшщъыьэюя"
}
for alph_name in alphabets:
    alphabets[alph_name] = set(alphabets[alph_name])
    print(alphabets[alph_name])
# Out:
# {'ш', 'г', 'ҟ', 'и', 'ь', 'ц', 'ы', 'қ', 'ӡ', 'ӷ', 'ҿ', 'џ', 'а', 'у', 'ҽ', 'ҩ', 'н', 'е', 'т', 'м', 'ԥ', 'р', 'к', 'ҳ', 'ҵ', 'л', 'с', 'ҭ', 'х', 'з', 'ч', 'ҷ', 'б', 'д', 'ф', 'о', 'п', 'в', 'ә'}
# {'ш', 'г', 'ь', 'ў', 'ц', 'ы', 'я', 'а', 'у', 'н', 'е', 'т', 'ё', 'м', 'э', 'й', 'ж', 'р', 'к', 'л', 'с', 'х', 'ю', 'з', 'ч', 'б', 'д', 'і', 'ф', 'о', 'п', 'в'}
# {'ш', 'г', 'и', 'ь', 'ц', 'ы', 'я', 'а', 'у', 'н', 'е', 'т', 'ё', 'м', 'э', 'й', 'ж', 'р', 'к', 'л', 'с', 'щ', 'х', 'ю', 'ъ', 'з', 'ч', 'б', 'д', 'ф', 'о', 'п', 'в'}
# {'ӯ', 'ш', 'г', 'и', 'я', 'қ', 'а', 'у', 'ӣ', 'н', 'е', 'т', 'ё', 'м', 'ғ', 'э', 'й', 'ж', 'р', 'к', 'ҳ', 'л', 'с', 'х', 'ю', 'ъ', 'з', 'ч', 'ҷ', 'б', 'д', 'ф', 'о', 'п', 'в'}
# {'ш', 'г', 'и', 'ӑ', 'ь', 'ц', 'ы', 'я', 'а', 'у', 'н', 'е', 'т', 'ё', 'м', 'э', 'й', 'ж', 'р', 'к', 'ӳ', 'л', 'ӗ', 'с', 'щ', 'х', 'ю', 'ъ', 'ҫ', 'з', 'ч', 'б', 'д', 'ф', 'о', 'п', 'в'}

# %% [markdown]
# ___

# %% [markdown]
# **Вопрос 1**. Сколько букв — общие для абхазского и беларусского алфавитов? Выведите число и все эти буквы.

# %%
#ваше решение

# %% [markdown]
# Правильный ответ: $24$.
# ___

# %% [markdown]
# **Вопрос 2**. Какие буквы есть и в абхазском, и в таджикском, но при этом отсутствуют в русском? Выведите их все.

# %%
#ваше решение

# %% [markdown]
# Правильный ответ: `қҳҷ` (в любом порядке).
# ___

# %% [markdown]
# **Вопрос 3**. Какие буквы есть или в беларусском, или в чувашском, но не в обоих сразу? Выведите их все.

# %%
#ваше решение

# %% [markdown]
# Правильный ответ: `ӑӗиіҫўӳщъ` (в любом порядке).
# ___

# %% [markdown]
# **Вопрос 4**. Если объединить алфавиты абхазского, русского и чувашского языков, сколько в получившемся мега-алфавите будет уникальных букв? Выведите число и все эти буквы.

# %%
#ваше решение

# %% [markdown]
# Правильный ответ: $51$.
# ___

# %% [markdown]
# **Вопрос 5**. Можно ли записать слово «**подъездами**» беларусским алфавитом? А таджикским? Для обоих алфавитов выведите `True` (если можно) или `False` (если нельзя). Если `False`, то укажите также, какие именно нужные буквы отсутствуют.

# %%
#ваше решение

# %% [markdown]
# (Правильный ответ: беларусским *нельзя*, потому что в нём нет букв «и» и «ъ», а таджикским *можно*.)
# ___
