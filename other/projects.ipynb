# %% [markdown]
# # Проекты

# %% [markdown]
# ### Официальное

# %% [markdown]
# > Загрузка проекта: **5 марта**, <u>23:59</u> ([ссылка для загрузки](https://edu.hse.ru/mod/assign/view.php?id=1539906))
# >
# > Защита проекта: **10 марта** на паре (14:40)

# %% [markdown]
# _**Информация из ЛМС**_:
#
# _____
#
# Загружает только один участник группы! **[В группу записаться](https://edu.hse.ru/mod/choicegroup/view.php?id=1428103) обязательно**, иначе не сможете загрузить.
#
# > _[Перевожу с ЛМС-ного на русский: вам нужно зайти в курс и «зарегистрировать» свою группу из 1–3 человек. Когда проект будет готов, только один человек из группы загружает все файлы. Не оставляйте запись в группу на последний момент ни в коем случае!]_
#
# Обязательно загружаете:
# - **файл с вашим кодом**
# - **файл(ы) с данными**, которые вы анализируете
#
# Дедлайн [сдачи работы] **является жёстким**. Не допускается сдача работы после установленного дедлайна. (При этом студент может явиться на защиту и показать проект, однако в таком случае может получить оценку не выше 6 баллов.)
#
# Защита проекта является обязательной для выставления оценки за проект. На защите студенты показывают результаты своей работы.
#
# Примеры вопросов, которые задаются студентам на защите проекта:
#
# - Что делает та или иная функция / метод, который был использован в проекте?
# - Что написано в конкретной строчке кода?
# - Как работает конкретная часть кода?
# - Как работает условная конструкция / цикл / функция, написанная студентом?
# - Если студент не может ответить на поставленные вопросы, то за проект выставляется оценка 0.
#
# Суммарно по критериям проекта можно набрать 10 баллов, что приравнивается к оценке 10 за работу. Защита проекта не оценивается. Оценка за проект выставляется после защиты. Оценка не округляется.
#
# ☝🏻 <u>Если на защите проекта был выявлен факт подлога, то выставляется оценка 0, а также предоставляется служебная записка на имя академического руководителя.</u>

# %% [markdown]
# _____

# %% [markdown]
# ### Неофициальное

# %% [markdown]
# Мои рекомендации к вашим проектам:
#
# 1. **Разделите код на функции**. До / в начале этапа написания кода разделите ваш проект на отдельные задачи (например: загрузить корпус текстов из файлов, токенизировать, посчитать определённую метрику…), выпишите себе список функций, которые будут решать каждую из этих задач, и затем работайте над этими функциями автономно. Это особенно полезно, если вы работаете в группе, — так задачи легче поделить между собой.
#    - Укажите в тетрадке, кто писал какую часть кода.
# 2. **Оформите код в виде единой (!) тетрадки**.
#    - Перед загрузкой перезапустите тетрадку и запустите все ячейки сверху вниз, чтобы убедиться, что проверяющ:ая сможет запустить ваш код, и всё сработает корректно. Не оставляйте это на последний момент — на этом этапе могут вскрыться небольшие ошибки, на исправление которых нужно время.
#    - Проверьте, что в финальном коде нет лишних ячеек, которые остались случайно.
#    - Обязательно корректно импортируйте все модули (желательно в отдельной ячейке в начале тетрадки), иначе запустить ваш проект не получится.
#    - Обязательно приложите все нужные файлы с данными, иначе запустить ваш проект не получится.
#    - Добавьте в тетрадку немного пояснений (либо в Markdown, либо комментированием `#` в ячейках с кодом), чтобы проверяющ:ая понимала, что происходит в каждом конкретном моменте кода, какие задачи выполняет та или иная функция, и так далее.
#    - Любые мета-пояснения (типа «мы воспользовались методом …, заметим, что он не идеален по причинам: …», «мы попытались также сделать …, но у нас не получилось решить некоторые ошибки», «к сожалению, не осталось времени на …») приветствуются.
# 4. При возникновении затруднений или ошибок **не стесняйтесь (а) гуглить** (например, обычное дело — загуглить текст, который выдаёт питон при ошибке) и **(б) спрашивать вопросы** в чате курса.
# 5. Не оставляйте всё на последний вечер.
#
# Удачи!
